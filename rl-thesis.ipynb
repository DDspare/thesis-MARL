# %%
cd epymarl
# Out:
# [Errno 2] No such file or directory: 'epymarl'
# /Users/sl_ai/rl-thesis

# %%
# !python3 src/main.py --config=mappo --env-config=gymma with env_args.time_limit=500 env_args.key="rware:rware-tiny-4ag-v1"
# Out:
# [DEBUG 11:32:37] git.cmd Popen(['git', 'version'], cwd=/Users/sl_ai/epymarl, stdin=None, shell=False, universal_newlines=False)
# [DEBUG 11:32:37] git.cmd Popen(['git', 'version'], cwd=/Users/sl_ai/epymarl, stdin=None, shell=False, universal_newlines=False)
# [DEBUG 11:32:37] git.util Failed checking if running in CYGWIN due to: FileNotFoundError(2, 'No such file or directory')
# [DEBUG 11:32:37] git.cmd Popen(['git', 'diff', '--cached', '--abbrev=40', '--full-index', '--raw'], cwd=/Users/sl_ai/epymarl, stdin=None, shell=False, universal_newlines=False)
# [DEBUG 11:32:37] git.cmd Popen(['git', 'diff', '--abbrev=40', '--full-index', '--raw'], cwd=/Users/sl_ai/epymarl, stdin=None, shell=False, universal_newlines=False)
# [DEBUG 11:32:37] git.cmd Popen(['git', 'cat-file', '--batch-check'], cwd=/Users/sl_ai/epymarl, stdin=<valid stream>, shell=False, universal_newlines=False)
# ...
